# %%
from alpaca.statistics.chisquared import get_chi2
from alpaca.statistics.functions import nsigmas
from alpaca import ALPcouplings

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12, 'text.usetex': True, 'font.family': 'serif', 'font.serif': 'Computer Modern Roman'})

# %%
transitions = [
    'B+ -> K+ a',
    'B0 -> K*0 a',
    'B+ -> K+ e e',
    'B0 -> K*0 e e',
    'B+ -> K+ mu mu',
    'B0 -> K*0 mu mu',
]

# %%
ma = 0.3
fa = 1e3

cu_vec_pos = np.logspace(-4, 0, 50)
ce_vec_pos= np.logspace(-4, 0, 50)

cu_pos, ce_pos = np.meshgrid(cu_vec_pos, ce_vec_pos)

# Flatten the meshgrid arrays
cu_flat = cu_pos.flatten()
ce_flat = ce_pos.flatten()

# Create a list to store the ALPcouplings objects
couplings_list = []

# Iterate over the flattened arrays and create ALPcouplings objects
for cu_val, ce_val in zip(cu_flat, ce_flat):
    coupling = ALPcouplings({'cuR': cu_val, 'clL': ce_val}, scale=fa, basis='derivative_above').match_run(5.1, 'VA_below', 'leadinglog') 
    couplings_list.append(coupling)

# Convert the list of couplings back to a numpy array and reshape it to the original meshgrid shape
couplings_array_pos = np.array(couplings_list).reshape(cu_pos.shape)

# Create fa_grid and ma_grid with the same shape as the meshgrid
fa_grid = np.full(cu_pos.shape, fa)
ma_grid = np.full(cu_pos.shape, ma)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[327], line 18
#      16 # Iterate over the flattened arrays and create ALPcouplings objects
#      17 for cu_val, ce_val in zip(cu_flat, ce_flat):
# ---> 18     coupling = ALPcouplings({'cuR': cu_val, 'clL': ce_val}, scale=fa, basis='derivative_above').match_run(5.1, 'VA_below', 'leadinglog')
#      19     couplings_list.append(coupling)
#      21 # Convert the list of couplings back to a numpy array and reshape it to the original meshgrid shape
#
# File /opt/anaconda3/lib/python3.12/site-packages/alpaca/rge/classes.py:285, in ALPcouplings.match_run(self, scale_out, basis, integrator, beta, match_2loops)
#     243 def match_run(self, scale_out: float, basis: str, integrator: str='scipy', beta: str='full', match_2loops = False) -> 'ALPcouplings':
#     244     """Match and run the couplings to another basis and energy scale.
#     245
#     246     Parameters
#    (...)
#     283         If attempting to translate to an unrecognized basis.
#     284     """
# --> 285     return self._match_run(scale_out, basis, integrator, beta, match_2loops)
#
# File /opt/anaconda3/lib/python3.12/site-packages/alpaca/rge/classes.py:296, in ALPcouplings._match_run(self, scale_out, basis, integrator, beta, match_2loops)
#     294 if self.scale > self.ew_scale and scale_out < self.ew_scale:
#     295     if self.basis in bases_above and basis in bases_below:
# --> 296         couplings_ew = self.match_run(self.ew_scale, 'massbasis_above', integrator, beta, self.ew_scale)
#     297         couplings_below = matching.match(couplings_ew, match_2loops)
#     298         return couplings_below.match_run(scale_out, basis, integrator, beta, self.ew_scale)
#
# File /opt/anaconda3/lib/python3.12/site-packages/alpaca/rge/classes.py:285, in ALPcouplings.match_run(self, scale_out, basis, integrator, beta, match_2loops)
#     243 def match_run(self, scale_out: float, basis: str, integrator: str='scipy', beta: str='full', match_2loops = False) -> 'ALPcouplings':
#     244     """Match and run the couplings to another basis and energy scale.
#     245
#     246     Parameters
#    (...)
#     283         If attempting to translate to an unrecognized basis.
#     284     """
# --> 285     return self._match_run(scale_out, basis, integrator, beta, match_2loops)
#
# File /opt/anaconda3/lib/python3.12/site-packages/alpaca/rge/classes.py:320, in ALPcouplings._match_run(self, scale_out, basis, integrator, beta, match_2loops)
#     318     return run_high.run_scipy(self, betafunc, scale_out).translate(basis)
#     319 elif integrator == 'leadinglog':
# --> 320     return run_high.run_leadinglog(self, betafunc, scale_out).translate(basis)
#     321 elif integrator == 'no_rge':
#     322     return ALPcouplings(self.values, scale_out, self.basis).translate(basis)
#
# File /opt/anaconda3/lib/python3.12/site-packages/alpaca/rge/run_high.py:182, in run_leadinglog(couplings, beta, scale_out)
#     167 def run_leadinglog(couplings: ALPcouplings, beta: Callable[[ALPcouplings], ALPcouplings], scale_out: float) -> ALPcouplings:
#     168     """Obtain the ALP couplings at a different scale using the leading log approximation
#     169
#     170     Parameters
#    (...)
#     179         Final energy scale, in GeV
#     180     """
# --> 182     result = couplings + beta(couplings) * (np.log(scale_out/couplings.scale)/(16*np.pi**2))
#     183     result.scale = scale_out
#     184     return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/alpaca/rge/run_high.py:125, in beta_full(couplings)
#     109 """beta function for the ALP couplings, including the full Yukawa dependence
#     110
#     111 Implements eq.(18) of 2012.12272
#    (...)
#     121     An object containing the beta functions of the ALP couplings
#     122 """
#     124 tildes = gauge_tilde(couplings)
# --> 125 pars = runSM(couplings.scale)
#     126 yu = np.matrix(pars['yu'])
#     127 yd = np.matrix(pars['yd'])
#
# File /opt/anaconda3/lib/python3.12/site-packages/alpaca/rge/runSM.py:22, in runSM(scale)
#      20 citations.register_inspire('Aebischer:2018bkb') #wilson
#      21 citations.register_inspire('Straub:2018kue') # ckmutil is inside flavio's repo
# ---> 22 wSM = wilson.classes.SMEFT(wilson.wcxf.WC('SMEFT', 'Warsaw', scale, {})).C_in # For the moment we reuse wilson's code for the SM case, i.e, with all Wilson coefficients set to zero. Maybe at some point we should implement our own version.
#      24 UuL, mu, UuR = ckmutil.diag.msvd(wSM['Gu'])
#      25 UdL, md, UdR = ckmutil.diag.msvd(wSM['Gd'])
#
# File /opt/anaconda3/lib/python3.12/site-packages/wilson/run/smeft/classes.py:34, in SMEFT.__init__(self, wc, get_smpar)
#      32 self.C_in = None
#      33 if wc is not None:
# ---> 34     self._set_initial_wcxf(wc, get_smpar=get_smpar)
#
# File /opt/anaconda3/lib/python3.12/site-packages/wilson/run/smeft/classes.py:77, in SMEFT._set_initial_wcxf(self, wc, get_smpar)
#      75     self.C_in.update(C)
#      76 if get_smpar:
# ---> 77     self.C_in.update(self._get_sm_scale_in())
#
# File /opt/anaconda3/lib/python3.12/site-packages/wilson/run/smeft/classes.py:254, in SMEFT._get_sm_scale_in(self, scale_sm)
#     252 _smeft = SMEFT(self.wc, get_smpar=False)
#     253 # Step 1: run the SM up, using the WCs at scale_input as (constant) estimate
# --> 254 _smeft.C_in.update(self._run_sm_scale_in(self.C_in, scale_sm=scale_sm))
#     255 # Step 2: run the WCs down in LL approximation
#     256 C_out = _smeft._rgevolve_leadinglog(scale_sm)
#
# File /opt/anaconda3/lib/python3.12/site-packages/wilson/run/smeft/classes.py:223, in SMEFT._run_sm_scale_in(self, C_out, scale_sm)
#     221 smeft_sm._set_initial(C_in_sm, scale_sm)
#     222 # run up (with 1% relative precision, ignore running of Wilson coefficients)
# --> 223 C_SM_high = smeft_sm._rgevolve(self.scale_in, newphys=False, rtol=0.001, atol=1)
#     224 C_SM_high = self._rotate_defaultbasis(C_SM_high)
#     225 return {k: v for k, v in C_SM_high.items() if k in SM_keys}
#
# File /opt/anaconda3/lib/python3.12/site-packages/wilson/run/smeft/classes.py:97, in SMEFT._rgevolve(self, scale_out, **kwargs)
#      92 """Solve the SMEFT RGEs from the initial scale to `scale_out`.
#      93 Returns a dictionary with parameters and Wilson coefficients at
#      94 `scale_out`. Additional keyword arguments will be passed to
#      95 the ODE solver `scipy.integrate.odeint`."""
#      96 self._check_initial()
# ---> 97 return rge.smeft_evolve(C_in=self.C_in,
#      98                     scale_in=self.scale_in,
#      99                     scale_out=scale_out,
#     100                     **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/wilson/run/smeft/rge.py:39, in smeft_evolve(C_in, scale_in, scale_out, newphys, **kwargs)
#      35 def smeft_evolve(C_in, scale_in, scale_out, newphys=True, **kwargs):
#      36     """Solve the SMEFT RGEs by numeric integration.
#      37
#      38     Input C_in and output C_out are dictionaries of arrays."""
# ---> 39     sol = _smeft_evolve(C_in, scale_in, scale_out, newphys=newphys, **kwargs)
#      40     return smeftutil.C_array2dict(sol.y[:, -1].view(complex))
#
# File /opt/anaconda3/lib/python3.12/site-packages/wilson/run/smeft/rge.py:29, in _smeft_evolve(C_in, scale_in, scale_out, newphys, **kwargs)
#      26     return beta.beta_array(C=smeftutil.C_array2dict(y.view(complex)),
#      27                            newphys=newphys).view(float) / (16 * pi**2)
#      28 y0 = smeftutil.C_dict2array(C_in).view(float)
# ---> 29 sol = solve_ivp(fun=fun,
#      30                 t_span=(log(scale_in), log(scale_out)),
#      31                 y0=y0, **kwargs)
#      32 return sol
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/integrate/_ivp/ivp.py:655, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     653 status = None
#     654 while status is None:
# --> 655     message = solver.step()
#     657     if solver.status == 'finished':
#     658         status = 0
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:63, in rk_step(fun, t, y, f, h, A, B, C, K)
#      61 K[0] = f
#      62 for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
# ---> 63     dy = np.dot(K[:s].T, a[:s]) * h
#      64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
#
# KeyboardInterrupt:

# %%
chi2_cuce_pos03 = get_chi2(transitions, ma_grid, couplings_array_pos, fa_grid, integrator='no_rge')

# %%
ma = 0.3
fa = 1e3

cu_vec_neg = -np.logspace(-4, 0, 100)
ce_vec_neg = np.logspace(-4, 0, 100)

cu_neg, ce_neg = np.meshgrid(cu_vec_neg, ce_vec_neg)

# Flatten the meshgrid arrays
cu_flat = cu_neg.flatten()
ce_flat = ce_neg.flatten()

# Create a list to store the ALPcouplings objects
couplings_list = []

# Iterate over the flattened arrays and create ALPcouplings objects
for cu_val, ce_val in zip(cu_flat, ce_flat):
    coupling = ALPcouplings({'cuR': cu_val, 'clL': ce_val}, scale=fa, basis='derivative_above').match_run(5.1, 'VA_below', 'leadinglog') 
    couplings_list.append(coupling)

# Convert the list of couplings back to a numpy array and reshape it to the original meshgrid shape
couplings_array_neg = np.array(couplings_list).reshape(cu_neg.shape)

# Create fa_grid and ma_grid with the same shape as the meshgrid
fa_grid = np.full(cu_neg.shape, fa)
ma_grid = np.full(cu_neg.shape, ma)

# %%
chi2_cuce_neg03 = get_chi2(transitions, ma_grid, couplings_array_neg, fa_grid, integrator='no_rge')

# %%
plt.figure(dpi=150)
fig, ax = plt.subplots(1,2,dpi=150, sharey=True, figsize=(10,5))
colors = {('B+ -> K+ a', 'Belle II'): 'cyan', ('B0 -> K*0 a', 'BaBar'): 'teal', ('B+ -> K+ e e', 'Belle II'): 'purple', ('B0 -> K*0 e e', 'Belle II'): 'magenta', ('B+ -> K+ mu mu', 'LHCb'): 'limegreen', ('B+ -> K+ mu mu', 'Belle II'): 'yellow', ('B+ -> K+ mu mu', 'CHARM'): 'green', ('B0 -> K*0 mu mu', 'LHCb'): 'red', ('B0 -> K*0 mu mu', 'Belle II'): 'orange'}
tex = {'B+ -> K+ a': r'$B^+ \to K^+ \nu \nu$', 'B0 -> K*0 a': r'$B^0 \to K^{*0} \nu \nu$', 'B+ -> K+ e e': r'$B^+ \to K^+ e^+ e^-$', 'B0 -> K*0 e e': r'$B^0 \to K^{*0} e^+ e^-$', 'B+ -> K+ mu mu': r'$B^+ \to K^+ \mu^+ \mu^-$', 'B0 -> K*0 mu mu': r'$B^0 \to K^{*0} \mu^+ \mu^-$'}
legend_elements = []



pl_pos = ax[1].contourf(cu_pos/fa, ce_pos/fa, nsigmas(np.real(chi2_cuce_pos03[('', 'Global')]),2), levels=list(np.linspace(0, 3, 100)), cmap='magma_r', vmax=3, extend='max')
for observable, chi2_obs in chi2_cuce_pos03.items():
    if observable == ('', 'Global'):
        break
    ax[1].contour(cu_pos/fa, ce_pos/fa, nsigmas(np.real(chi2_obs), 2), levels=[2], colors = colors[observable])
    legend_elements.append(plt.Line2D([0], [0], color=colors[observable], label=tex[observable[0]] + ' (' + observable[1] + ')'))

pl_neg = ax[0].contourf(-cu_neg/fa, ce_neg/fa, nsigmas(np.real(chi2_cuce_neg03[('', 'Global')]),2), levels=list(np.linspace(0, 3, 100)), cmap='magma_r', vmax=3, extend='max')
for observable, chi2_obs in chi2_cuce_neg03.items():
    if observable == ('', 'Global'):
        break
    ax[0].contour(-cu_neg/fa, ce_neg/fa, nsigmas(np.real(chi2_obs), 2), levels=[2], colors = colors[observable])
    # legend_elements.append(plt.Line2D([0], [0], color=colors[observable], label=tex[observable[0]] + ' (' + observable[1] + ')'))

for i in ax:
    i.set_xscale('log')
    i.set_yscale('log')

ax[0].invert_xaxis()

ax[0].set_xlabel(r'$-c_u/f_a$ [GeV$^{-1}$]')
ax[1].set_xlabel(r'$c_u/f_a$ [GeV$^{-1}$]')
ax[0].set_ylabel(r'$c_e/f_a$ [GeV$^{-1}$]')
cb = plt.colorbar(pl_pos, extend='max')
cb.set_label(r'Exclusion significance [$\sigma$]')
cb.set_ticks([0, 1, 2, 3])
plt.legend(handles = legend_elements, loc='center left', bbox_to_anchor=(1, 0.5), borderaxespad=9, fontsize=8)
plt.title(r'$m_a = 0.3$ GeV, $f_a = 1$ TeV')
# Out:
# Text(0.5, 1.0, '$m_a = 0.3$ GeV, $f_a = 1$ TeV')

# %%
ma = 2
fa = 1e3

cu_vec = np.logspace(-4, 0, 10)
cd_vec = -np.logspace(-4, 0, 10)

cu, cd = np.meshgrid(cu_vec, cd_vec)

# Flatten the meshgrid arrays
cu_flat = cu.flatten()
cd_flat = cd.flatten()

# Create a list to store the ALPcouplings objects
couplings_list = []

# Iterate over the flattened arrays and create ALPcouplings objects
for cu_val, cd_val in zip(cu_flat, cd_flat):
    coupling = ALPcouplings({'cuR': cu_val, 'cdR': cd_val}, scale=fa, basis='derivative_above').match_run(5.1, 'VA_below', 'leadinglog') 
    couplings_list.append(coupling)

# Convert the list of couplings back to a numpy array and reshape it to the original meshgrid shape
couplings_array = np.array(couplings_list).reshape(cu.shape)

# Create fa_grid and ma_grid with the same shape as the meshgrid
fa_grid = np.full(cu.shape, fa)
ma_grid = np.full(cu.shape, ma)

# %%
transitions = [
    'B+ -> K+ a',
    'B0 -> K*0 a',
    'B+ -> K+ e e',
    'B0 -> K*0 e e',
    'B+ -> K+ mu mu',
    'B0 -> K*0 mu mu',
]

# %%
chi2_cucd = get_chi2(transitions, ma_grid, couplings_array, fa_grid, integrator='no_rge')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/scipy/interpolate/_rgi.py:460: ComplexWarning: Casting complex values to real discards the imaginary part
#   xi = np.asarray(xi, dtype=float)

# %%
plt.figure(dpi=150)
colors = {('B+ -> K+ a', 'Belle II'): 'cyan', ('B0 -> K*0 a', 'BaBar'): 'teal', ('B+ -> K+ e e', 'Belle II'): 'purple', ('B0 -> K*0 e e', 'Belle II'): 'magenta', ('B+ -> K+ mu mu', 'LHCb'): 'limegreen', ('B+ -> K+ mu mu', 'Belle II'): 'yellow', ('B+ -> K+ mu mu', 'CHARM'): 'green', ('B0 -> K*0 mu mu', 'LHCb'): 'red', ('B0 -> K*0 mu mu', 'Belle II'): 'orange'}
tex = {'B+ -> K+ a': r'$B^+ \to K^+ \nu \nu$', 'B0 -> K*0 a': r'$B^0 \to K^{*0} \nu \nu$', 'B+ -> K+ e e': r'$B^+ \to K^+ e^+ e^-$', 'B0 -> K*0 e e': r'$B^0 \to K^{*0} e^+ e^-$', 'B+ -> K+ mu mu': r'$B^+ \to K^+ \mu^+ \mu^-$', 'B0 -> K*0 mu mu': r'$B^0 \to K^{*0} \mu^+ \mu^-$'}
legend_elements = []

pl = plt.contourf(cu/fa, -cd/fa, nsigmas(np.real(chi2_cucd[('', 'Global')]),2), levels=list(np.linspace(0, 3, 100)), cmap='magma_r', vmax=3, extend='max')
for observable, chi2_obs in chi2_cucd.items():
    if observable == ('', 'Global'):
        break
    plt.contour(cu/fa, -cd/fa, nsigmas(np.real(chi2_obs), 2), levels=[2], colors = colors[observable])
    legend_elements.append(plt.Line2D([0], [0], color=colors[observable], label=tex[observable[0]] + ' (' + observable[1] + ')'))
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')

plt.xlabel(r'$c_u/f_a$ [GeV$^{-1}$]')
plt.ylabel(r'$c_d/f_a$ [GeV$^{-1}$]')
cb = plt.colorbar(pl, extend='max')
cb.set_label(r'Exclusion significance [$\sigma$]')
cb.set_ticks([0, 1, 2, 3])
plt.legend(handles = legend_elements, loc='center left', bbox_to_anchor=(1, 0.5), borderaxespad=9, fontsize=8)
plt.title(r'$m_a = 0.3$ GeV, $f_a = 1$ TeV')
# Out:
# Text(0.5, 1.0, '$m_a = 0.3$ GeV, $f_a = 1$ TeV')
