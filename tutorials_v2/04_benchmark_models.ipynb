# %%
from alpaca.models import model_library
import sympy as sp
from IPython import display # pretty printing in jupyter. Does not work on regular python
from alpaca.models import KSVZ_model, fermion

# %% [markdown]
# ## Matching of UV models to ALP Lagrangian

# %%
charge = sp.symbols(r'\mathcal{X}')
charge_u = sp.symbols(r'\mathcal{X}_u')
charge_d = sp.symbols(r'\mathcal{X}_d')

# %% [markdown]
# ### KSVZ-like models

# %% [markdown]
# Models from [1610.07593](https://arxiv.org/abs/1610.07593) to check we obtain the same results

# %%
R1 = model_library.fermion('3','1',sp.Rational(-1,3),charge)
R2 = model_library.fermion('3','1',sp.Rational(2,3),charge)
R3 = model_library.fermion('3','2',sp.Rational(1,6),charge)
R4 = model_library.fermion('3','2',sp.Rational(-5,6),charge)
R5 = model_library.fermion('3','2',sp.Rational(7,6),charge)
R6 = model_library.fermion('3','3',sp.Rational(-1,3),charge)
R7 = model_library.fermion('3','3',sp.Rational(2,3),charge)
R8 = model_library.fermion('3','3',sp.Rational(-4,3),charge)
R9 = model_library.fermion('6_bar','1',sp.Rational(-1,3),charge)
R10 = model_library.fermion('6_bar','1',sp.Rational(2,3),charge)
R11 = model_library.fermion('6_bar','2',sp.Rational(1,6),charge)
R12 = model_library.fermion('8','1',-1,charge)
R13 = model_library.fermion('8','2',sp.Rational(-1,2),charge)
R14 = model_library.fermion('15','1',sp.Rational(-1,3),charge)
R15 = model_library.fermion('15','1',sp.Rational(2,3),charge)

list_of_fermions=[R1,R2,R3,R4,R5,R6,R7, R8, R9, R10, R11, R12, R13, R14, R15]

# %%
list_of_KSVZ_models: list[model_library.KSVZ_model] = []
for i, fermion in enumerate(list_of_fermions):
    name = 'R' + str(i+1)
    list_of_KSVZ_models.append(model_library.KSVZ_model(name, [fermion]))
text = ''
for models in list_of_KSVZ_models:
   text += models.model_name + '\n' + r'\\' #+ '\n~' + r'\\' + '\n'
   text += models.couplings_latex() + '\n' + r'\\' + '\n'
   text += r'E/N = ' + str(models.E_over_N()) + '\n' + r'\\' + '\n~' + r'\\' + '\n'
display.Math(text)
# Out:
# $\displaystyle R1
# \\\begin{align}
# c_g &= - \frac{\mathcal{X}}{2} \nonumber \\
# c_B &= - \frac{\mathcal{X}}{3} \nonumber
# \end{align}
# \\
# E/N = 2/3
# \\
# ~\\
# R2
# \\\begin{align}
# c_g &= - \frac{\mathcal{X}}{2} \nonumber \\
# c_B &= - \frac{4 \mathcal{X}}{3} \nonumber
# \end{align}
# \\
# E/N = 8/3
# \\
# ~\\
# R3
# \\\begin{align}
# c_g &= - \mathcal{X} \nonumber \\
# c_B &= - \frac{\mathcal{X}}{6} \nonumber \\
# c_W &= - \frac{3 \mathcal{X}}{2} \nonumber
# \end{align}
# \\
# E/N = 5/3
# \\
# ~\\
# R4
# \\\begin{align}
# c_g &= - \mathcal{X} \nonumber \\
# c_B &= - \frac{25 \mathcal{X}}{6} \nonumber \\
# c_W &= - \frac{3 \mathcal{X}}{2} \nonumber
# \end{align}
# \\
# E/N = 17/3
# \\
# ~\\
# R5
# \\\begin{align}
# c_g &= - \mathcal{X} \nonumber \\
# c_B &= - \frac{49 \mathcal{X}}{6} \nonumber \\
# c_W &= - \frac{3 \mathcal{X}}{2} \nonumber
# \end{align}
# \\
# E/N = 29/3
# \\
# ~\\
# R6
# \\\begin{align}
# c_g &= - \frac{3 \mathcal{X}}{2} \nonumber \\
# c_B &= - \mathcal{X} \nonumber \\
# c_W &= - 6 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 14/3
# \\
# ~\\
# R7
# \\\begin{align}
# c_g &= - \frac{3 \mathcal{X}}{2} \nonumber \\
# c_B &= - 4 \mathcal{X} \nonumber \\
# c_W &= - 6 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 20/3
# \\
# ~\\
# R8
# \\\begin{align}
# c_g &= - \frac{3 \mathcal{X}}{2} \nonumber \\
# c_B &= - 16 \mathcal{X} \nonumber \\
# c_W &= - 6 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 44/3
# \\
# ~\\
# R9
# \\\begin{align}
# c_g &= - \frac{5 \mathcal{X}}{2} \nonumber \\
# c_B &= - \frac{2 \mathcal{X}}{3} \nonumber
# \end{align}
# \\
# E/N = 4/15
# \\
# ~\\
# R10
# \\\begin{align}
# c_g &= - \frac{5 \mathcal{X}}{2} \nonumber \\
# c_B &= - \frac{8 \mathcal{X}}{3} \nonumber
# \end{align}
# \\
# E/N = 16/15
# \\
# ~\\
# R11
# \\\begin{align}
# c_g &= - 5 \mathcal{X} \nonumber \\
# c_B &= - \frac{\mathcal{X}}{3} \nonumber \\
# c_W &= - 3 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 2/3
# \\
# ~\\
# R12
# \\\begin{align}
# c_g &= - 3 \mathcal{X} \nonumber \\
# c_B &= - 8 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 8/3
# \\
# ~\\
# R13
# \\\begin{align}
# c_g &= - 6 \mathcal{X} \nonumber \\
# c_B &= - 4 \mathcal{X} \nonumber \\
# c_W &= - 4 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 4/3
# \\
# ~\\
# R14
# \\\begin{align}
# c_g &= - 10 \mathcal{X} \nonumber \\
# c_B &= - \frac{5 \mathcal{X}}{3} \nonumber
# \end{align}
# \\
# E/N = 1/6
# \\
# ~\\
# R15
# \\\begin{align}
# c_g &= - 10 \mathcal{X} \nonumber \\
# c_B &= - \frac{20 \mathcal{X}}{3} \nonumber
# \end{align}
# \\
# E/N = 2/3
# \\
# ~\\
# $

# %%
su3repr = []
su2repr = []
hypercharge = []
e_over_n = []

with open('table_heavyquarks_2412.17896.tex', 'rt') as f:
    for line in f.readlines():
        line = line.split('&')
        su3 = line[0].strip()
        if su3.startswith(r'$\overline{'):
            su3 = su3[11:-2] + '_bar'
        su3 = su3.replace(r'$^\prime$', "'")
        su3repr.append(su3)
        su2repr.append(line[1].strip())
        hypercharge.append(sp.Rational(line[2].strip(), 6))
        e_over_n.append(sp.Rational(line[3].strip()))
        
for i in range(len(su3repr)):
    e0 = KSVZ_model('', [model_library.fermion(su3repr[i], su2repr[i], hypercharge[i], 1)]).E_over_N()
    if e0 != e_over_n[i]:
        print(f'Error in ({su3repr[i]}, {su2repr[i]}, {hypercharge[i]}): {e0} != {e_over_n[i]}')
    else:
        print(rf'Q ~({su3repr[i]}, {su2repr[i]}, {hypercharge[i]}): E/N= {e0}')
# Out:
# Q ~(3, 1, -1/3): E/N= 2/3
# Q ~(3, 1, 2/3): E/N= 8/3
# Q ~(3, 2, 1/6): E/N= 5/3
# Q ~(3, 2, -5/6): E/N= 17/3
# Q ~(3, 2, 7/6): E/N= 29/3
# Q ~(3, 3, -1/3): E/N= 14/3
# Q ~(3, 3, 2/3): E/N= 20/3
# Q ~(3, 3, -4/3): E/N= 44/3
# Q ~(3, 3, 5/3): E/N= 62/3
# Q ~(3, 4, -5/6): E/N= 35/3
# Q ~(3, 4, 1/6): E/N= 23/3
# Q ~(3, 4, 7/6): E/N= 47/3
# Q ~(6_bar, 1, 2/3): E/N= 16/15
# Q ~(6_bar, 1, -1/3): E/N= 4/15
# Q ~(6_bar, 2, 1/6): E/N= 2/3
# Q ~(8, 1, -1): E/N= 8/3
# Q ~(8, 2, -1/2): E/N= 4/3
# Q ~(15, 1, -1/3): E/N= 1/6
# Q ~(15, 1, 2/3): E/N= 2/3
# Q ~(15, 2, 1/6): E/N= 5/12
# Q ~(3, 1, -7/3): E/N= 98/3
# Q ~(3_bar, 1, 4/3): E/N= 32/3
# Q ~(3_bar, 1, -5/3): E/N= 50/3
# Q ~(3, 1, 8/3): E/N= 128/3
# Q ~(3, 2, -11/6): E/N= 65/3
# Q ~(3_bar, 2, -13/6): E/N= 89/3
# Q ~(3, 4, -11/6): E/N= 83/3
# Q ~(3, 4, 13/6): E/N= 107/3
# Q ~(3, 5, -4/3): E/N= 68/3
# Q ~(3, 5, -1/3): E/N= 38/3
# Q ~(3, 5, 2/3): E/N= 44/3
# Q ~(3, 5, 5/3): E/N= 86/3
# Q ~(6, 1, -5/3): E/N= 20/3
# Q ~(6, 1, 4/3): E/N= 64/15
# Q ~(6_bar, 1, -7/3): E/N= 196/15
# Q ~(6, 2, -7/6): E/N= 58/15
# Q ~(6, 2, 5/6): E/N= 34/15
# Q ~(6_bar, 2, -11/6): E/N= 26/3
# Q ~(6, 3, -2/3): E/N= 8/3
# Q ~(6, 3, 1/3): E/N= 28/15
# Q ~(6, 3, 4/3): E/N= 88/15
# Q ~(6, 4, -1/6): E/N= 46/15
# Q ~(6_bar, 4, -5/6): E/N= 14/3
# Q ~(8, 1, 0): E/N= 0
# Q ~(8, 1, -2): E/N= 32/3
# Q ~(8, 2, -3/2): E/N= 20/3
# Q ~(8, 3, 0): E/N= 16/9
# Q ~(8, 3, -1): E/N= 40/9
# Q ~(8, 4, -1/2): E/N= 4
# Q ~(10, 1, 0): E/N= 0
# Q ~(10, 1, 1): E/N= 4/3
# Q ~(10, 2, -1/2): E/N= 2/3
# Q ~(10, 2, 1/2): E/N= 2/3
# Q ~(10, 2, 3/2): E/N= 10/3
# Q ~(10, 3, 0): E/N= 8/9
# Q ~(10, 3, 1): E/N= 20/9
# Q ~(15_bar, 1, 4/3): E/N= 8/3
# Q ~(15_bar, 1, -5/3): E/N= 25/6
# Q ~(15_bar, 2, 5/6): E/N= 17/12
# Q ~(15_bar, 2, -7/6): E/N= 29/12
# Q ~(15, 3, -1/3): E/N= 7/6
# Q ~(15, 3, 2/3): E/N= 5/3
# Q ~(15_bar, 4, -1/6): E/N= 23/12
# Q ~(3, 2, -17/6): E/N= 149/3
# Q ~(3, 2, 19/6): E/N= 185/3
# Q ~(3, 3, -7/3): E/N= 110/3
# Q ~(3_bar, 3, -8/3): E/N= 140/3
# Q ~(3, 5, -7/3): E/N= 134/3
# Q ~(3, 6, -11/6): E/N= 113/3
# Q ~(3, 6, -5/6): E/N= 65/3
# Q ~(3, 6, 1/6): E/N= 53/3
# Q ~(3, 6, 7/6): E/N= 77/3
# Q ~(3, 6, 13/6): E/N= 137/3
# Q ~(6, 2, -13/6): E/N= 178/15
# Q ~(6_bar, 2, -17/6): E/N= 298/15
# Q ~(6, 3, -5/3): E/N= 124/15
# Q ~(6_bar, 3, -7/3): E/N= 44/3
# Q ~(6, 4, -7/6): E/N= 94/15
# Q ~(6, 4, 11/6): E/N= 166/15
# Q ~(6, 5, -2/3): E/N= 88/15
# Q ~(6_bar, 5, -1/3): E/N= 76/15
# Q ~(6_bar, 5, -4/3): E/N= 136/15
# Q ~(8, 2, -5/2): E/N= 52/3
# Q ~(8, 3, -2): E/N= 112/9
# Q ~(8, 4, -3/2): E/N= 28/3
# Q ~(8, 5, 0): E/N= 16/3
# Q ~(8, 5, -1): E/N= 8
# Q ~(10, 1, -1): E/N= 4/3
# Q ~(10, 1, 2): E/N= 16/3
# Q ~(10, 3, -1): E/N= 20/9
# Q ~(10, 4, -1/2): E/N= 2
# Q ~(10, 4, 1/2): E/N= 2
# Q ~(10, 4, 3/2): E/N= 14/3
# Q ~(15_bar, 2, 11/6): E/N= 65/12
# Q ~(15_bar, 3, 4/3): E/N= 11/3
# Q ~(15, 4, -5/6): E/N= 35/12
# Q ~(15, 4, 7/6): E/N= 47/12
# Q ~(15', 1, -1/3): E/N= 2/21
# Q ~(15', 1, 2/3): E/N= 8/21
# Q ~(15', 2, 1/6): E/N= 5/21
# Q ~(24, 1, -1/3): E/N= 8/75
# Q ~(24, 1, 2/3): E/N= 32/75
# Q ~(24, 2, 1/6): E/N= 4/15
# Q ~(27, 1, -1): E/N= 1
# Q ~(27, 2, -1/2): E/N= 1/2
# Q ~(42, 1, -1/3): E/N= 4/51
# Q ~(42, 1, 2/3): E/N= 16/51
# Q ~(3, 3, -10/3): E/N= 212/3
# Q ~(3, 4, -17/6): E/N= 167/3
# Q ~(6_bar, 1, 8/3): E/N= 256/15
# Q ~(6, 5, -5/3): E/N= 172/15
# Q ~(10, 1, -2): E/N= 16/3
# Q ~(10, 2, -3/2): E/N= 10/3
# Q ~(10, 4, -3/2): E/N= 14/3
# Q ~(15, 1, -7/3): E/N= 49/6
# Q ~(24_bar, 1, 4/3): E/N= 128/75
# Q ~(24_bar, 1, -5/3): E/N= 8/3
# Q ~(24_bar, 2, 5/6): E/N= 68/75
# Q ~(24_bar, 2, -7/6): E/N= 116/75
# Q ~(24_bar, 3, 1/3): E/N= 56/75
# Q ~(24, 3, 2/3): E/N= 16/15
# Q ~(27, 1, 0): E/N= 0
# Q ~(27, 3, 0): E/N= 2/3
# Q ~(27, 3, -1): E/N= 5/3
# Q ~(35, 1, 0): E/N= 0
# Q ~(35, 1, 1): E/N= 2/3
# Q ~(42_bar, 1, 4/3): E/N= 64/51
# Q ~(3_bar, 1, 10/3): E/N= 200/3
# Q ~(3, 1, 11/3): E/N= 242/3
# Q ~(3, 2, -23/6): E/N= 269/3
# Q ~(6, 1, -11/3): E/N= 484/15
# Q ~(6_bar, 1, -10/3): E/N= 80/3
# Q ~(8, 1, -3): E/N= 24
# Q ~(10, 1, -3): E/N= 12
# Q ~(10_bar, 1, -3): E/N= 12
# Q ~(21_bar, 1, 4/3): E/N= 16/15
# Q ~(21, 1, -1/3): E/N= 1/15
# Q ~(21, 1, 2/3): E/N= 4/15
# Q ~(21_bar, 2, 5/6): E/N= 17/30
# Q ~(21_bar, 2, -1/6): E/N= 1/6
# Q ~(35, 1, -1): E/N= 2/3

# %% [markdown]
# ### DFSZ-like models

# %% [markdown]
# Models from [1705.05370](https://arxiv.org/abs/1705.05370) to check we obtain the same results

# %%
DFSZ1 = model_library.model('DFSZ-I', {'eR': charge, 'uR': charge, 'dR': charge})
DFSZ2 = model_library.model('DFSZ-II', {'eR': -charge, 'uR': charge, 'dR': charge})
DFSZ3a = model_library.model('DFSZ-IIIa', {'eR': -(2*charge_u+charge_d), 'uR': charge_u, 'dR': charge_d})
DFSZ3b = model_library.model('DFSZ-IIIb', {'eR': charge_d,  'uR': charge_u, 'dR': charge_d})
DFSZ3c = model_library.model('DFSZ-IIIc', {'eR': charge_u+2*charge_d, 'uR': charge_u, 'dR': charge_d})
DFSZ3d = model_library.model('DFSZ-IIId', {'eR': -charge_u, 'uR': charge_u, 'dR': charge_d})

list_of_DFSZ_models=[DFSZ1, DFSZ2, DFSZ3a, DFSZ3b, DFSZ3c, DFSZ3d]

# %%
text = ''
for models in list_of_DFSZ_models:
   text += models.model_name + '\n' + r'\\' #+ '\n~' + r'\\' + '\n'
   text += models.couplings_latex() + '\n' + r'\\' + '\n'
   text += r'E/N = ' + str(models.E_over_N()) + '\n' + r'\\' + '\n~' + r'\\' + '\n'
display.Math(text)
# Out:
# $\displaystyle DFSZ-I
# \\\begin{align}
# c_{u_R} &= - \mathcal{X} \nonumber \\
# c_{d_R} &= - \mathcal{X} \nonumber \\
# c_{e_R} &= - \mathcal{X} \nonumber \\
# c_g &= 3 \mathcal{X} \nonumber \\
# c_B &= 8 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 8/3
# \\
# ~\\
# DFSZ-II
# \\\begin{align}
# c_{u_R} &= - \mathcal{X} \nonumber \\
# c_{d_R} &= - \mathcal{X} \nonumber \\
# c_{e_R} &= \mathcal{X} \nonumber \\
# c_g &= 3 \mathcal{X} \nonumber \\
# c_B &= 2 \mathcal{X} \nonumber
# \end{align}
# \\
# E/N = 2/3
# \\
# ~\\
# DFSZ-IIIa
# \\\begin{align}
# c_{u_R} &= - \mathcal{X}_u \nonumber \\
# c_{d_R} &= - \mathcal{X}_d \nonumber \\
# c_{e_R} &= \mathcal{X}_d + 2 \mathcal{X}_u \nonumber \\
# c_g &= \frac{3 \mathcal{X}_d}{2} + \frac{3 \mathcal{X}_u}{2} \nonumber \\
# c_B &= - 2 \mathcal{X}_d - 2 \mathcal{X}_u \nonumber
# \end{align}
# \\
# E/N = -4/3
# \\
# ~\\
# DFSZ-IIIb
# \\\begin{align}
# c_{u_R} &= - \mathcal{X}_u \nonumber \\
# c_{d_R} &= - \mathcal{X}_d \nonumber \\
# c_{e_R} &= - \mathcal{X}_d \nonumber \\
# c_g &= \frac{3 \mathcal{X}_d}{2} + \frac{3 \mathcal{X}_u}{2} \nonumber \\
# c_B &= 4 \mathcal{X}_d + 4 \mathcal{X}_u \nonumber
# \end{align}
# \\
# E/N = 8/3
# \\
# ~\\
# DFSZ-IIIc
# \\\begin{align}
# c_{u_R} &= - \mathcal{X}_u \nonumber \\
# c_{d_R} &= - \mathcal{X}_d \nonumber \\
# c_{e_R} &= - 2 \mathcal{X}_d - \mathcal{X}_u \nonumber \\
# c_g &= \frac{3 \mathcal{X}_d}{2} + \frac{3 \mathcal{X}_u}{2} \nonumber \\
# c_B &= 7 \mathcal{X}_d + 7 \mathcal{X}_u \nonumber
# \end{align}
# \\
# E/N = 14/3
# \\
# ~\\
# DFSZ-IIId
# \\\begin{align}
# c_{u_R} &= - \mathcal{X}_u \nonumber \\
# c_{d_R} &= - \mathcal{X}_d \nonumber \\
# c_{e_R} &= \mathcal{X}_u \nonumber \\
# c_g &= \frac{3 \mathcal{X}_d}{2} + \frac{3 \mathcal{X}_u}{2} \nonumber \\
# c_B &= \mathcal{X}_d + \mathcal{X}_u \nonumber
# \end{align}
# \\
# E/N = 2/3
# \\
# ~\\
# $
